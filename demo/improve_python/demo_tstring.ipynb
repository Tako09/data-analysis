# %% [markdown]
# # T-stringの実演
# この機能は、従来の f-strings と見た目は似ていますが、**「文字列をすぐに作らず、構造データとして保持する」**という点が決定的に違います。

# %%
# Templateオブジェクトのインポート
from string.templatelib import Template
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Templateオブジェクトのインポート
# ----> 2 from string.templatelib import Template
#
# ModuleNotFoundError: No module named 'string.templatelib'; 'string' is not a package

# %%
name = "Python"
# f-string: すぐに "Hello Python" という文字列になる
f_res = f"Hello {name}" 

# t-string: 構造を保持したオブジェクトになる
t_res = t"Hello {name}"

print(type(t_res)) # <class 'string.templatelib.Template'>
print(t_res.strings) # ('Hello ', '')
print(t_res.values)  # ('Python',)
