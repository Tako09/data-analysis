# %% [markdown]
# ---
# title: "Steamのオープンデータを使ったEDA"
# description: "Steamのオープンデータを使ったEDAを実施し、売れ筋のカテゴリなどを分析する"
# date: "2026-02-01"
# categories: ["Analysis", "Steam"]
# jupyter: python3
# ---

# %%
import os
import requests
import pandas as pd

# %%
# api_key = os.environ.get("API_KEY")
api_key = "__"

print(api_key)

# %%
def GetOwnedGames(api_key, uid):
    url = "http://api.steampowered.com/IPlayerService/GetOwnedGames/v1/?key={}&steamid={}&format=json".format(
        api_key, uid
    )
    r = requests.get(url)
    data = json.loads(r.text)
    return data["response"]
